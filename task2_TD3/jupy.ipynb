# %%
import torch
O = 5
A = 2
D = torch.empty((10,O,A,1,O,1)) #<D_size,s,a,r,s',d> 
D.shape
# Out:
# torch.Size([10, 5, 2, 1, 5, 1])

# %%
# !pip install gymnasium
# !pip install mujoco
# !pip install imageio
import gymnasium as gym

# %%
import gymnasium as gym
import torch
import numpy as np
env = gym.make('Hopper-v5',exclude_current_positions_from_observation=True)
obs,info = env.reset()
env.observation_space.shape
print(obs)
obs1 = np.concat((obs[:5],obs[7:]),axis=0)
print(obs1)
obs2 = np.concat((obs[:5],obs[7:]),axis=-1)
print(obs2)
next_obs = torch.tensor(obs,dtype=torch.float32,device='device')
next_obs
# Out:
# [ 1.24588440e+00  3.05326236e-03  2.60189127e-03 -2.02740776e-03
#  -2.68946182e-03  1.92334490e-03 -4.36620385e-03  4.83665787e-03
#  -3.16891182e-05  3.90629830e-03 -5.50844887e-04]
# [ 1.24588440e+00  3.05326236e-03  2.60189127e-03 -2.02740776e-03
#  -2.68946182e-03  4.83665787e-03 -3.16891182e-05  3.90629830e-03
#  -5.50844887e-04]
# [ 1.24588440e+00  3.05326236e-03  2.60189127e-03 -2.02740776e-03
#  -2.68946182e-03  4.83665787e-03 -3.16891182e-05  3.90629830e-03
#  -5.50844887e-04]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 12
#      10 obs2 = np.concat((obs[:5],obs[7:]),axis=-1)
#      11 print(obs2)
# ---> 12 next_obs = torch.tensor(obs,dtype=torch.float32,device='cuda')
#      13 next_obs
#
# ...

# %%
[0 for i in range(0,7)]
# Out:
# [0, 0, 0, 0, 0, 0, 0]

# %%
padding_mask
# Out:
# tensor([False,  True, False, False, False])

# %%
import torch
padding_mask = torch.zeros((B,L,)).bool()
padding_mask[:,1] = True
padding_mask
p2 = torch.repeat_interleave(padding_mask,5).reshape(2,5,5).transpose(-2,-1)
p2 = torch.repeat_interleave(padding_mask,5).reshape(2,5,5).transpose(-2,-1)
p2
# Out:
# tensor([[[False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False]],
#
#         [[False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False],
#          [False,  True, False, False, False]]])

# %%
import numpy as np
act_features = 3
actions = np.array([1/act_features for i in range(act_features)])

# %%
actions
# Out:
# array([0.33333333, 0.33333333, 0.33333333])
