# %%
import torch
O = 5
A = 2
D = torch.empty((10,O,A,1,O,1)) #<D_size,s,a,r,s',d> 
D.shape
# Out:
# torch.Size([10, 5, 2, 1, 5, 1])

# %%
# !pip install gymnasium
# !pip install mujoco
# !pip install imageio
import gymnasium as gym

# %%
env = gym.make('Hopper-v5')
obs,info = env.reset()
info
# Out:
# {'x_position': np.float64(0.0025935260531853334),
#  'z_distance_from_origin': np.float64(0.0025359138104863455)}

# %%
[0 for i in range(0,7)]
# Out:
# [0, 0, 0, 0, 0, 0, 0]

# %%
import torch
padding_mask = torch.zeros((5,)).bool()
padding_mask[1] = True
padding_mask
# Out:
# tensor([False,  True, False, False, False])
